# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Tray Glover
#
# This is an example of creating Jupyter notebooks.
#
# ![Tray Glover](attachment:4ec3e1d3-3d9e-44c1-a470-279847029059.jpeg)
# <img src="headshot.jpeg" width="100"/>

# %%
hello = "hello world2"
print(hello)
user_input = input(prompt='Give me your name: ')
# Out:
# hello world2

# %%
print(user_input)
# Out:
# Tray
